# %% [markdown]
# <a href="https://colab.research.google.com/github/anvitha-jain/MLColab/blob/master/Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **German Credit Data - MidTerm**
#
# >
#
# ---
#
# ###  **Name**: Anvitha Shubhaveer Jain
# ###    **ID**: 013738478
#
# ---

# %% [markdown]
# # **Tabel of Contents**
#
#
# > 1.  German Credit DataSet
#         1.1.  Read Data CSV
#         1.2.  Data Cleaning
#         1.3.  Data Analysis/ EDA
# 2. Dimensionality reduction using PCA     ....<-10
# 3. Clustering
#         3.1. GMM       <-1
#         3.2. K-means   <-2
# 4. Classification
#         4.1. Linear Reg      <-3
#         4.2. Logistic Reg    <-4
#         4.3. Naive Bayes     <-5
#         4.4. Decision Tree   <-6
#         4.5. Random Forest   <-7
#         4.6. Support Vector Machine - SVM   <-8
#         4.7. K-Nearest Neighbor - KNN       <-9
#
# All 10 Algorithms: from Clustering = 2, Classification = 7 and PCA are solved but numbered differently.

# %% [markdown]
# # **1. German Credit DataSet**

# %% [markdown]
# When a bank receives a loan application, based on the applicant’s profile the bank has to make a decision regarding whether to go ahead with the loan approval or not. Two types of risks are associated with the bank’s decision –
#
# If the applicant is a good credit risk, i.e. is likely to repay the loan, then not approving the loan to the person results in a loss of business to the bank If the applicant is a bad credit risk, i.e. is not likely to repay the loan, then approving the loan to the person results in a financial loss to the bank
#
# **Objective of Analysis:**
#
#
# > Minimization of risk and maximization of profit on behalf of the bank.
#
#
#
# > To minimize loss from the bank’s perspective, the bank needs a decision rule regarding who to give approval of the loan and who not to. An applicant’s demographic and socio-economic profiles are considered by loan managers before a decision is taken regarding his/her loan application.
#
# The German Credit Data contains data on 20 variables and the classification whether an applicant is considered a Good or a Bad credit risk for 1000 loan applicants.
#
# A predictive model developed on this data is expected to provide a bank manager guidance for making a decision whether to approve a loan to a prospective applicant based on his/her profiles.

# %% [markdown]
# <B>Description of the German credit dataset.</B>
#
# 1. <B>Title:</B> German Credit data
#
# 2. <B>Source Information</B>
#
# Professor Dr. Hans Hofmann Institut f"ur Statistik und "Okonometrie Universit"at Hamburg FB Wirtschaftswissenschaften Von-Melle-Park 5 2000 Hamburg 13
#
# 3. <B>Number of Instances:</B> 1000
#
# 4. Two datasets are provided. the original dataset, in the form provided by Prof. Hofmann, contains categorical/symbolic attributes and is in the file "german.data".
#
# 5. For algorithms that need numerical attributes, Strathclyde University produced the file "german.data-numeric". This file has been edited and several indicator variables added to make it suitable for algorithms which cannot cope with categorical variables. Several attributes that are ordered categorical (such as attribute 17) have been coded as integer. This was the form used by StatLog.
#
# 6. <B>Number of Attributes german:</B> 20 (7 numerical, 13 categorical) Number of Attributes german.numer: 24 (24 numerical)
#
# 7. <B>Attribute description for german</B>
#
# Attribute 1: (qualitative) (4 items -> 2 bits) Status of existing checking account
#
#     A11 : ... < 0 DM
#     A12 : 0 <= ... < 200 DM
#     A13 : ... >= 200 DM / salary assignments for at least 1 year A14 : no checking account
#
# Attribute 2: (numerical) (Gaussian normalization) Duration in month
#
# Attribute 3: (qualitative) (4 items -> 2 bits) Credit history
#
#       A30 : no credits taken/ all credits paid back duly
#       A31 : all credits at this bank paid back duly
#       A32 : existing credits paid back duly till now
#       A33 : delay in paying off in the past
#       A34 : critical account/ other credits existing (not at this bank)
#
# Attribute 4: (qualitative) Purpose
#
#       A40 : car (new)
#       A41 : car (used)
#       A42 : furniture/equipment
#       A43 : radio/television
#       A44 : domestic appliances
#       A45 : repairs
#       A46 : education
#       A47 : (vacation - does not exist?)
#       A48 : retraining
#       A49 : business
#       A410 : others
#
# Attribute 5: (numerical) (Gaussian normalization) Credit amount
#
# Attibute 6: (qualitative) Savings account/bonds
#
#       A61 : ... < 100 DM
#       A62 : 100 <= ... < 500 DM
#       A63 : 500 <= ... < 1000 DM
#       A64 : .. >= 1000 DM A65 : unknown/ no savings account
#
# Attribute 7: (qualitative) Present employment since
#
#       A71 : unemployed
#       A72 : ... < 1 year
#       A73 : 1 <= ... < 4 years
#       A74 : 4 <= ... < 7 years
#       A75 : .. >= 7 years
#
# Attribute 8: (numerical) (Gaussian normalization) Installment rate in percentage of disposable income
#
# Attribute 9: (qualitative) Personal status and sex
#
#       A91 : male : divorced/separated
#       A92 : female : divorced/separated/married
#       A93 : male : single
#       A94 : male : married/widowed
#       A95 : female : single
#
# Attribute 10: (qualitative) Other debtors / guarantors
#
#       A101 : none
#       A102 : co-applicant
#       A103 : guarantor
#
# Attribute 11: (numerical) (Gaussian normalization) Present residence since
#
# Attribute 12: (qualitative) (4 items -> 2 bits) Property
#
#       A121 : real estate
#       A122 : if not
#       A121 : building society savings agreement/ life insurance
#       A123 : if not
#       A121/A122 : car or other, not in attribute 6
#       A124 : unknown / no property
#
# Attribute 13: (numerical) (Gaussian normalization) Age in years
#
# Attribute 14: (qualitative) Other installment plans
#
#       A141 : bank
#       A142 : stores
#       A143 : none
#
# Attribute 15: (qualitative) Housing
#
#       A151 : rent
#       A152 : own
#       A153 : for free
#
# Attribute 16: (numerical) (Gaussian normalization) Number of existing credits at this bank
#
# Attribute 17: (qualitative) (4 items -> 2 bits) Job
#
#       A171 : unemployed/ unskilled - non-resident
#       A172 : unskilled - resident
#       A173 : skilled employee / official
#       A174 : management/ self-employed/ highly qualified employee/ officer
#
# Attribute 18: (numerical) (Gaussian normalization) Number of people being liable to provide maintenance for
#
# Attribute 19: (qualitative) (Binary) Telephone
#
#       A191 : none
#       A192 : yes, registered under the customers name
#
# Attribute 20: (qualitative) (Binary) foreign worker
#
#       A201 : yes
#       A202 : no
#
#  8. <B>Cost Matrix</B>
#
# This dataset requires use of a cost matrix (see below)
#
# . | 1 | 2
# --- | --- | ---
# **1** | 0 | 1
# **2** | 5 | 0
#
#
#
# (1 = Good, 2 = Bad)
#
# the rows represent the actual classification and the columns the predicted classification. It is worse to class a customer as good when they are bad (5), than it is to class a customer as bad when they are good (1).

# %% [markdown]
# # **1.1. Read Data CSV**

# %% [markdown]
# <B>Notes:</B>
#
# - DM stands for Deutsche Mark, the unit of currency in Germany.
# - Owns_telephone: German phone rates are very high, so fewer people own telephones.
# - Foreign_worker: There are millions of foreign worker working in Germany
# - 20 attributes used in judging a loan applicant. The goal is the classify the applicant into one of two categories, good or bad, which is the last attribute
# - This dataset is typical of data used in data mining: we have 1000 records.

# %% [markdown]
# 1. First We need to analyze the data set (use the numerical version). Visualize the Data Set. This can be done in various ways, from single visualizations to doing pairplot
# 2. Cluster the data, use GMM and then k-means. visulaize it. Interpret it. Compare.
# 3. use linear regression to see thre trends, interpret them,
# 4. Then classify the data -- pick a couple of good things to classify by -- use logistic regression for a binary classification (maybe default no default) (maybe other attribute) and
# 5. use Random Forest to classify if they will default or not.

# %% [markdown]
# ### **Import the necessary libraries**

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.decomposition import PCA 
from sklearn.preprocessing import normalize
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import silhouette_score
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %% [markdown]
# ### **Read Data**
# Original Dataset
# http://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/
#
# Numeric Dataset Stored in "[MLFall2019/crimerate-seers/MidtermData/GermanDataNumeric.csv](MLFall2019/crimerate-seers/MidtermData/GermanDataNumeric.csv)"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Original Dataset from  http://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.data

# Currently data is stored in drive path " MLFall2019/crimerate-seers/MidtermData/GermanDataNumeric.csv "
germandf = pd.read_csv("/content/drive/My Drive/MLFall2019/crimerate-seers/MidtermData/GermanDataNumeric.csv")
germandf.head()
# Out:
#    StatusCheckingAccount  ...  CostMatrix
# 0                      1  ...           1
# 1                      2  ...           2
# 2                      4  ...           1
# 3                      1  ...           1
# 4                      1  ...           2
#
# [5 rows x 25 columns]

# %%
# print inital shapes for csv i.e tha germandataframe = germandf
print("Initial Shape of German Credit Data:",germandf.shape,'\n')
# Out:
# Initial Shape of German Credit Data: (1000, 25)

# %%
#Copying the original dataframe (germandf) to form pca dataframe
germandf_pca=germandf
#get the shape of the pca dataframe
print("Initial Shape of PCA - German Credit Data:",germandf_pca.shape,'\n')
# Out:
# Initial Shape of PCA - German Credit Data: (1000, 25)

# %%
#decribe the dataframe
germandf.describe()
# Out:
#        StatusCheckingAccount  ...   CostMatrix
# count            1000.000000  ...  1000.000000
# mean                2.577000  ...     1.300000
# std                 1.257638  ...     0.458487
# min                 1.000000  ...     1.000000
# 25%                 1.000000  ...     1.000000
# 50%                 2.000000  ...     1.000000
# 75%                 4.000000  ...     2.000000
# max                 4.000000  ...     2.000000
#
# [8 rows x 25 columns]

# %%
germandf.CostMatrix.value_counts()
# Out:
# 1    700
# 2    300
# Name: CostMatrix, dtype: int64

# %% [markdown]
# ### **From counting the values in Cost Matrix column from the german dataframe we can analyze that:**
#
# * **700** were granted the credit. Therfore, they are **good credit customers.**
#
# * **300** weren't granted the credit. Therfore, they are  **bad credit customers.**
#
# We can observe that the ***data_set is not balanced*** *with positive and negative differences of 400*.

# %% [markdown]
# .

# %% [markdown]
# # **1.2. Cleaning Data**

# %%
#Check the Null values in Dataset

germandf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
# StatusCheckingAccount                           1000 non-null int64
# DurationMonth                                   1000 non-null int64
# CreditHistory                                   1000 non-null int64
# CreditAmount                                    1000 non-null int64
# SavingsAccount/bonds                            1000 non-null int64
# PresentEmployment                               1000 non-null int64
# PersonalStatusAndSex                            1000 non-null int64
# PresentResidence                                1000 non-null int64
# Property                                        1000 non-null int64
# AgeInYears                                      1000 non-null int64
# OtherInstallmentPlans                           1000 non-null int64
# NoOfExistingCreditsAtThisBank                   1000 non-null int64
# ...

# %%
#checking count of missing values from the Dataset

germandf.isnull().sum()
# Out:
# StatusCheckingAccount                           0
# DurationMonth                                   0
# CreditHistory                                   0
# CreditAmount                                    0
# SavingsAccount/bonds                            0
# PresentEmployment                               0
# PersonalStatusAndSex                            0
# PresentResidence                                0
# Property                                        0
# AgeInYears                                      0
# OtherInstallmentPlans                           0
# NoOfExistingCreditsAtThisBank                   0
# NoOfPeopleBeingLiableToProvideMaintenanceFor    0
# Telephone                                       0
# ForeignWorker                                   0
# NewCar                                          0
# UsedCar                                         0
# None_Guarantors                                 0
# Co-applicant_Guarantors                         0
# ...

# %% [markdown]
# # **1.3. Data Analysis/ EDA**

# %%
#Number of uniques values in each column in Dataset
germandf.nunique()
# Out:
# StatusCheckingAccount                             4
# DurationMonth                                    33
# CreditHistory                                     5
# CreditAmount                                    125
# SavingsAccount/bonds                              5
# PresentEmployment                                 5
# PersonalStatusAndSex                              4
# PresentResidence                                  4
# Property                                          4
# AgeInYears                                       53
# OtherInstallmentPlans                             3
# NoOfExistingCreditsAtThisBank                     4
# NoOfPeopleBeingLiableToProvideMaintenanceFor      2
# Telephone                                         2
# ForeignWorker                                     2
# NewCar                                            2
# UsedCar                                           2
# None_Guarantors                                   2
# ...

# %% [markdown]
# ### **Based on above analysis the features used for analysis are**
#
# .  | Colums/features | value count
# --- | --- | ---
#   |  **CreditAmount**  |  125
# | **AgeInYears** |  53
# | **DurationMonth** | 33
#
# CreditAmount having maximum unique features, is plotted against Age and Duration Month

# %%
#Plot Credit Amount V/s Age
plt.scatter(germandf['CreditAmount'],germandf["AgeInYears"])
plt.title('Credit Amount V/s Age Scatter plot')
plt.xlabel("Credit Amount")
plt.ylabel("Age in years")
plt.figure()

# %%
#Plot Credit Amount V/s Duration Month
plt.scatter(germandf['CreditAmount'],germandf["DurationMonth"])
plt.title('Credit Amount V/s Duration Month Scatter plot')
plt.xlabel("Credit Amount")
plt.ylabel("Duration Month")
plt.figure()

# %% [markdown]
# ### <B> From the above visualizations we can infer that: </B>
#
#    1. Most people are between the age of 20-30
#
#    2. Credit Amount and Duration Month are linear correlated
#
#    3. people with low Credit Amount are of Age 20-40(Adults)
#
#    4. Short term credit with credit range 20 t0 50 yield maximum customer and profits.

# %% [markdown]
# ## Correlation or Heat Map
#
# ***
# Correlation Map is used to obtain information about the highly correlated features of our dataset, which helps in more accurate predections. Higher the linearity, probability of accuracy will be higher.

# %%
# Correlation Map
corr = germandf.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot = True)
plt.title('Correlation Mapping between features')
# Out:
# Text(0.5, 1, 'Correlation Mapping between features')

# %% [markdown]
# * ### **Heat Map shows that there is no strong correlation particularly between any two variables.**
#
# * ### **It also shows that Credit Amount and Duration Month may have moderate correlation.**

# %%
#without regression
pairplot = germandf
# .drop(columns = ['StatusCheckingAccount','CreditHistory','NewCar','UsedCar','SavingsAccount/bonus','PresentEmployment','PersonalStatusAndSex','Property','None_Guarantors','Co-applicant_Guarantors','HousingRent','HousingOwn','job_unemployed/unskilled-non-resident','job_unskilled-resident','job_skilledEemployee/official','Telephone','ForeignWorker'])    
sns.pairplot(pairplot, kind="scatter")
plt.show()

# %% [markdown]
# .

# %% [markdown]
# **From Pairplot we can see that Credit Amount, Duration Month and Age are somehow linearly related to each other**

# %% [markdown]
# # **2. Dimensionality reduction using Principal  Component Analysis PCA.**

# %% [markdown]
# PCA is an unsupervised linear dimensionality reduction algorithm to find a more meaningful basis or coordinate system for our data and works based on covariance matrix to find the strongest features of the samples .

# %%
X = germandf.drop('CostMatrix', 1).values #independent variables
y = germandf["CostMatrix"].values #target variables

pca = PCA(n_components=16)
X = pca.fit_transform(X)

# %%
# https://github.com/vigneshj6/GermanCreditData/blob/master/germanCredit.ipynb

y = KMeans().fit_predict(germandf)
X_norm = normalize(germandf)
y_PCA = PCA(n_components=2).fit_transform(X_norm,2)
y_PCA.shape

# %%
plt.scatter(germandf['CreditAmount'],germandf['AgeInYears'],c=y)
plt.title('Credit Amount V/s Age Before PCA')
plt.xlabel("Credit Amount")
plt.ylabel("Age in years")
#Simple Scatter plot with the dataset features
plt.figure()
#Scatter plot after applying PCA to the dataset
plt.title('Credit Amount V/s Age After PCA')
plt.xlabel("Credit Amount")
plt.ylabel("Age in years")
plt.scatter(y_PCA[:,0],y_PCA[:,1],c=y)

# %% [markdown]
# **The above graphs show that difference before and after PCA respectively**

# %% [markdown]
# # **3. Clustering**

# %% [markdown]
# Clustering analysis finds clusters of data objects that are similar in some sense to one another. The members of a cluster are more like each other than they are like members of other clusters. The goal of clustering analysis is to find high-quality clusters such that the inter-cluster similarity is low and the intra-cluster similarity is high.

# %% [markdown]
# # **3.1. GMM**
#
# A Gaussian mixture model(GMM) is a probabilistic model that assumes all the data points are generated from a mixture of a finite number of Gaussian distributions with unknown parameters.

# %%
# Apply GMM for the whole dataset
def GMM_clusters(numOfClusters,data):
    gmm = GaussianMixture(n_components=numOfClusters).fit(data)
    labels = gmm.predict(data)
    return labels

germandf['GMM_Label'] = GMM_clusters(6,germandf)
print("GMM Clusters:")
germandf['GMM_Label'].value_counts()
# Out:
# GMM Clusters:
# 1    672
# 0    246
# 5     31
# 3     23
# 4     16
# 2     12
# Name: GMM_Label, dtype: int64

# %% [markdown]
# # **GMM with PCA**

# %% [markdown]
# Use PCA on the dataset so that it can select the features that are most important for classification.

# %%
# Apply GMM on PCA dataset
def PCAplt(df,labels,algo):
    pca = PCA(n_components = 3).fit_transform(df)
    plt.figure(figsize=(10,6))
    plt.scatter(pca[:,0],pca[:,1], c = labels)
    plt.title('Clustering %s' %algo)
    plt.xlabel("PC1")
    plt.ylabel("PC2")

# %%
PCAplt(germandf,germandf['GMM_Label'],'GMM')

# %% [markdown]
# **GMM -1 (CreditAmount  vs DurationMonth)**

# %%
gmm1 = germandf[['CreditAmount', 'DurationMonth']]
from sklearn.mixture import GaussianMixture
def doGMM(X, nclust=2):
    model = GaussianMixture(n_components=nclust)
    model.fit(X)
    clust_labels5 = model.predict(X)
    return (clust_labels5)

clust_labels5 = doGMM(gmm1)
gmm = pd.DataFrame(clust_labels5)
gmm1.insert((gmm1.shape[1]),'gmm',gmm)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
scatter = ax.scatter(gmm1['CreditAmount'],gmm1['DurationMonth'],
                     c=gmm[0],s=50)
ax.set_title('GMM Clustering for Credit Amount  vs Duration Month')
ax.set_xlabel('Credit Amount')
ax.set_ylabel('Duration Month')
plt.colorbar(scatter)

# %% [markdown]
# **GMM -2 (AgeInYears  vs CreditHistory)**

# %%
gmm2 = germandf[['AgeInYears' , 'CreditHistory']]
from sklearn.mixture import GaussianMixture
def doGMM(X, nclust=2):
    model = GaussianMixture(n_components=nclust)
    model.fit(X)
    clust_labels5 = model.predict(X)
    return (clust_labels5)

clust_labels5 = doGMM(gmm2)
gmm = pd.DataFrame(clust_labels5)
gmm2.insert((gmm2.shape[1]),'gmm',gmm)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
scatter = ax.scatter(gmm2['AgeInYears'], gmm2['CreditHistory'], c=gmm[0],s=50)
ax.set_title('GMM Clustering for Age vs Credit History')
ax.set_xlabel('Credit History')
ax.set_ylabel('Age in years')
plt.colorbar(scatter)

# %% [markdown]
# Use GMM to clluster the users in the dataset.
#
# Use AIC and BIC values to find the optimum number of components to be used in GMM

# %% [markdown]
# **Silhouette_Score Comparision for GMM**

# %%
aic = dict()
bic = dict()
for k in range(1,11):
	estimator = GaussianMixture(n_components = k, random_state=0)
	res = estimator.fit(germandf)
	ic1 = estimator.aic(germandf)
	ic2 = estimator.bic(germandf)
	aic[k] = ic1
	bic[k] = ic2
    
aic_df = pd.Series(aic)
bic_df = pd.Series(bic)

temp = {'AIC' : aic_df,
     'BIC' : bic_df}
ic_df = pd.DataFrame(temp)
ax = ic_df.plot(title='AIC/BIC of GMM')
ax.set_xlabel('Number of clusters')
ax.set_ylabel('AIC/BIC')
plt.plot(3,aic_df[3],'ro')
plt.plot(3,bic_df[3],'ro')

# %% [markdown]
# From the figure above, we can see that considering both AIC and BIC, the number of clusters should be 3.

# %%
from matplotlib.patches import Ellipse
import numpy as np
def draw_ellipse(position, covariance, ax=None, **kwargs):
    """Draw an ellipse with a given position and covariance"""
    ax = ax or plt.gca()
    if covariance.shape == (2, 2):
        U, s, Vt = np.linalg.svd(covariance)
        angle = np.degrees(np.arctan2(U[1, 0], U[0, 0]))
        width, height = 2 * np.sqrt(s)
    else:
        angle = 0
        width, height = 2 * np.sqrt(covariance)
    
    # Draw the Ellipse
    for nsig in range(1, 4):
        ax.add_patch(Ellipse(position, nsig * width, nsig * height,
                             angle, **kwargs))
        
def plot_gmm(gmm, X, label=True, ax=None):
    ax = ax or plt.gca()
    labels = gmm.fit(X).predict(X)
    if label:
        ax.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis', zorder=2)
    else:
        ax.scatter(X[:, 0], X[:, 1], s=40, zorder=2)
    ax.axis('equal')
    
    w_factor = 0.2 / gmm.weights_.max()
    for pos, covar, w in zip(gmm.means_, gmm.covariances_, gmm.weights_):
        draw_ellipse(pos, covar, alpha=w * w_factor)

# %%
from matplotlib.patches import Ellipse
import numpy as np
g1 = germandf['DurationMonth'].values
g2 = germandf['AgeInYears'].values
X = np.array(list(zip(g1, g2)))
print(X)

n_components = np.arange(1,21)
gmm = GMM(n_components=5, covariance_type='full',verbose=0,verbose_interval=10,max_iter=5000).fit(X)
labels = gmm.predict(X)
plt.xlabel('Age in years')
plt.ylabel('Duration  Month')
plt.scatter(X[:,1],X[:, 0], c=labels, s= 40, cmap='viridis')
plot_gmm(gmm,X)
# Out:
# [[ 6 67]
#  [48 22]
#  [12 49]
#  ...
#  [12 38]
#  [45 23]
#  [45 27]]

# %% [markdown]
# The above diagram shows the GMM in Clusters

# %% [markdown]
# **Calculate Silhouette_Score for GMM**

# %%
from sklearn.metrics import silhouette_score
gmm_silhoute_score = silhouette_score(X, labels, metric='euclidean')
print('Silhouette Score:', gmm_silhoute_score)
# Out:
# Silhouette Score: 0.25675237627931174

# %% [markdown]
# # **3.2 K-Means**
#
#
# K-means clustering is one of the simplest and popular unsupervised machine learning algorithms. It will group or cluster the items based on their similarity.

# %%
# def k_means(germandf,no_of_clusters):
#     kmeans = KMeans(n_clusters=no_of_clusters)
#     kmeans_model = kmeans.fit(germandf)
#     return kmeans

# %% [markdown]
# Elbow Method is used to get the best fit or ideal value for the "K" in K-means algorithm

# %%
# Elbow Method
def elbow(germandf):
    wcss = []
    for i in range(1,11):
        kmeans = k_means(germandf,i)
        wcss.append(kmeans.inertia_) #within-cluster sums of squares
    plt.figure(figsize=(10,8))
    plt.plot(range(1,11),wcss,'bx-')
    plt.title('The Elbow Method')
    plt.xlabel('Number of clusters')
    plt.ylabel('WCSS')
    plt.show()
    

elbow(germandf)

# %% [markdown]
# ## From the Elbow cure we can infere that  **K=2 for our model**.

# %%
kmeans = k_means(germandf,2)
kmeans.cluster_centers_
# Out:
# array([[2.46666667e+00, 3.51777778e+01, 2.51666667e+00, 8.29611111e+01,
#         2.32777778e+00, 3.37222222e+00, 2.72222222e+00, 2.88888889e+00,
#         2.95000000e+00, 3.68000000e+01, 2.61666667e+00, 1.47222222e+00,
#         1.17222222e+00, 1.63888889e+00, 1.01666667e+00, 2.00000000e-01,
#         2.72222222e-01, 9.16666667e-01, 5.55555556e-02, 1.61111111e-01,
#         6.00000000e-01, 1.66666667e-02, 8.33333333e-02, 5.44444444e-01,
#         1.42777778e+00, 8.83333333e-01],
#        [2.60121951e+00, 1.77695122e+01, 2.55121951e+00, 2.16804878e+01,
#         2.05609756e+00, 3.38658537e+00, 2.67317073e+00, 2.83536585e+00,
#         2.22804878e+00, 3.52707317e+01, 2.68780488e+00, 1.39268293e+00,
#         1.15121951e+00, 1.35243902e+00, 1.04146341e+00, 2.41463415e-01,
#         6.58536585e-02, 9.04878049e-01, 3.78048780e-02, 1.82926829e-01,
#         7.37804878e-01, 2.31707317e-02, 2.25609756e-01, 6.48780488e-01,
#         1.27195122e+00, 1.00609756e+00]])

# %% [markdown]
# **K-Means-1:CreditAmount vs DurationMonth**

# %%
k1 = germandf[['CreditAmount' , 'DurationMonth']]

# %%
clusterNum = 2
k_means = KMeans(init = "k-means++",n_clusters = clusterNum)
k_means.fit(k1)
k1['labels']=k_means.labels_
k_means.cluster_centers_
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# array([[21.58629131, 17.67319461],
#        [82.37704918, 35.32240437]])

# %%
sns.lmplot('CreditAmount', 'DurationMonth', 
           data=k1, 
           fit_reg=False, 
           hue="labels",  
           scatter_kws={"marker": "D", 
                        "s": 100})
plt.title('Credit Amount vs Duration Month ')
plt.xlabel('Credit Amount')
plt.ylabel('Duration Month')
# Out:
# Text(26.029192708333333, 0.5, 'Duration Month')

# %% [markdown]
# ### K-Means-2: CreditHistory vs AgeInYears

# %%
k2 = germandf[['CreditHistory', 'AgeInYears']]

# %%
clusterNum = 2
k_means = KMeans(init = "k-means++",n_clusters = clusterNum)
k_means.fit(k2)
k2['labels']=k_means.labels_
k_means.cluster_centers_
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# array([[ 2.46556474, 29.74655647],
#        [ 2.75547445, 50.91240876]])

# %%
sns.lmplot('CreditHistory', 'AgeInYears', 
           data=k2, 
           fit_reg=False, 
           hue="labels",  
           scatter_kws={"marker": "D", 
                        "s": 100})
plt.title('Age vs Credit card History')
plt.xlabel('Credit Card History')
plt.ylabel('Age')
# Out:
# Text(26.029192708333333, 0.5, 'Age')

# %% [markdown]
# # **K-Means with PCA**

# %%
from sklearn.metrics import silhouette_score
from sklearn import metrics
age = germandf['AgeInYears'].values
duration= germandf['DurationMonth'].values
X = np.array(list(zip(age, duration)))
kmeans = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300,n_init = 10 , random_state = 0)
kmeans.fit_predict(X)

print ('Silhouette Score:', metrics.silhouette_score(X, labels, metric='euclidean'))
# Out:
# Silhouette Score: 0.25675237627931174

# %% [markdown]
# From both GMM and K-Means clustering , we have calculated the silhoute score , to show distinct clusters are present in both methods.
#
# . | Clustering | Silhouette Score
# --- | --- | ---
# 1. | GMM | 0.3429407986441174
# 2. | K-Means | 0.25675237627931174
#
# As GMM has more Silhouette Score value = 0.3429407986441174 GMM is more prefered for the dataset.

# %% [markdown]
# ### ***Train_Test_Split the data set into 80% training and 20% of testing groups***

# %%
#spliting in X and y values
X = germandf.drop('CostMatrix', axis=1)
y = germandf['CostMatrix']

# %%
# spliting the train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state = 100)

# %% [markdown]
# test_size=.20 which inferes that train data is 80% and test data is 20% of the whole dataset.
